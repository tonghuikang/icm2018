# %%
import numpy as np
import matplotlib.pylab as plt

plt.figure(figsize=(6,4))
PVC_datapoints = [
["Gender and name",0.008102356,2.9],
["Marital status:",0.030562818,8.3],
["photos and videos:",0.045238707,12.2],
["Home address:",0.062646252,17.4],
["Purchase history",0.078099395,22.6],
["location:",0.116972815,38.4],
["credit card:",0.130906643,45.1],
["SSN:",0.150798963,55.7],
["passwords:",0.183232622,75.8],
["medical:",0.193439847,82.9],
]

for item in range(len(PVC_datapoints)):
    plt.text(PVC_datapoints[item][1],PVC_datapoints[item][2], "x")

PIC_datapoints = [
# ["Full web profile:",0.753268558,20],
["Current location:",0.001710917,0.0004],
["Marital Status:",0.066454192,0.09],
["Web Browsing history",0.004763487,0.0018],
["Email:",0.056358333,0.07],
["Health condition",0.11744972,0.22]    
]

for item in range(len(PIC_datapoints)):
    plt.text(PIC_datapoints[item][1],PIC_datapoints[item][2], "x")
    
x = np.linspace(0.001,0.4,1000)
#y = np.exp(7.601402335 * x**(1/3.6054))
#y2 = np.exp(8.517393171* x**(1/2.55))
#y3 = np.exp(9.210440367* x**(1/2.329356))

y = np.exp(8.160803921 * x**(1/2.688567)) -1 
y2 = np.exp(4.615120517* x**(1/0.6811)) -1
y3 = np.exp(8.160803921 * x**(1/0.1)) -1


# plt.semilogy(x,y, label = "PVC")
# plt.semilogy(x,y2, label = "PIC")
# plt.semilogy(x,y3, label = "NC")
plt.plot(x,y, label = "PVC")
plt.plot(x,y2, label = "PIC")
plt.plot(x,y3, label = "NC")
plt.yscale("symlog", linthreshy=0.001)
plt.legend(loc="best")
plt.ylabel("Value")
plt.xlabel("Quality of information")
    
plt.show()
    

# 0.001, 2.689, 5.0, 8.0, 14.0

plt.figure(figsize=(6,4))
x = np.linspace(0,1,1000)
plt.plot(x,np.exp(8.160803921 * x**(1/0.001)) -1, label = "b+c = 0.001")
plt.plot(x,np.exp(8.160803921 * x**(1/2.689)) -1, label = "b+c = 2.689")
plt.plot(x,np.exp(8.160803921 * x**(1/5.0)) -1, label = "b+c = 5.0")
plt.plot(x,np.exp(8.160803921 * x**(1/8.0)) -1, label = "b+c = 8.0")
plt.plot(x,np.exp(8.160803921 * x**(1/14.0)) -1, label = "b+c = 14.0")
plt.ylabel("Value")
plt.legend(loc="best")
plt.xlabel("Quality of information")
plt.show()

# M is = 1000, 3500, 5000

plt.figure(figsize=(6,4))
x = np.linspace(0,1,1000)
plt.plot(x,np.exp(np.log(1000) * x**(1/2.688567)) -1, label = "M = 1000")
plt.plot(x,np.exp(np.log(3000) * x**(1/2.688567)) -1, label = "M = 3000")
plt.plot(x,np.exp(np.log(5000) * x**(1/2.688567)) -1, label = "M = 5000")
# plt.plot(x,np.exp(8.160803921 * x**(1/8.0)) -1, label = "b+c = 8.0")
# plt.plot(x,np.exp(8.160803921 * x**(1/14.0)) -1, label = "b+c = 14.0")
plt.ylabel("Value")
plt.legend(loc="best")
plt.xlabel("Quality of information")
plt.show()

# %%
# Out:
#   File "<ipython-input-8-6d5c5b2f0daf>", line 1
#     from __future__ import braces
# SyntaxError: not a chance
